# %% [markdown]
# # <font color='#FFE15D'>**Week 15: KNN 💜⬌💛**</font>

# %% [markdown]
# ## **🔸 KNN (sklearn)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
data = np.loadtxt('data/ex2data1.txt' , delimiter=',')

X = data[: , :-1].copy()
y = data[: , -1].copy().astype(np.int64)

normz = StandardScaler()
X = normz.fit_transform(X)
plt.scatter(X[: , 0] , X[: , 1] , c=y , cmap='jet' , ec='k');

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X , y)
# Out:
# KNeighborsClassifier()

# %%
xmin , xmax = X.min(0) , X.max(0)
x1 = np.linspace(xmin[0] , xmax[0] , 50)
x2 = np.linspace(xmin[1] , xmax[1] , 50)
xm1 , xm2 = np.meshgrid(x1 , x2)
xf1 , xf2 = xm1.flatten() , xm2.flatten()
Xf = np.stack((xf1 , xf2) , axis=1)

yf = model.predict(Xf)
ym = yf.reshape(xm1.shape)

plt.contourf(xm1 , xm2 , ym , cmap='jet' , alpha=0.5);
plt.scatter(X[: , 0] , X[: , 1] , c=y , cmap='jet' , ec='k');

# %% [markdown]
# ## *Weighted Voting*

# %%
model = KNeighborsClassifier(n_neighbors=7 , weights='distance')
model.fit(X , y)
# Out:
# KNeighborsClassifier(n_neighbors=7, weights='distance')

# %%
xmin , xmax = X.min(0) , X.max(0)
x1 = np.linspace(xmin[0] , xmax[0] , 50)
x2 = np.linspace(xmin[1] , xmax[1] , 50)
xm1 , xm2 = np.meshgrid(x1 , x2)
xf1 , xf2 = xm1.flatten() , xm2.flatten()
Xf = np.stack((xf1 , xf2) , axis=1)

yf = model.predict(Xf)
ym = yf.reshape(xm1.shape)

plt.contourf(xm1 , xm2 , ym , cmap='jet' , alpha=0.5);
plt.scatter(X[: , 0] , X[: , 1] , c=y , cmap='jet' , ec='k');
